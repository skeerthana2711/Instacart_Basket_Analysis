# %% [markdown]
# # 4.6 COMBINING & EXPORTING DATA
# ** **
# Part 2
# **SCRIPT CONTENTS:**
#
# 1. Importing Libraries & Files
# 2. Merging DataFrame
# 3. Exporting Merged DataFrame: **orders_products_merged.pkl**

# %%
#Importing libraries
import pandas as pd
import numpy as np
import os

# %%
path= r'C:\Users\S Keerthana\Desktop\Career Foundry\assignment\Instacart Basket Analysis'

# %%
#Importing combined data set
df_ords_prods_comb = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
#Importing products cleaned dataset
df_prods_cleaned = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'departments_checked.csv'), index_col = False)

# %%
#Check the shape of the imported dataframe
df_ords_prods_comb.shape
# Out:
# (32434489, 12)

# %%
#Check the shape of the imported dataframe
df_prods_cleaned.shape
# Out:
# (49677, 6)

# %%
#Check the output
df_ords_prods_comb.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    order_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                  2                  8                     0.0         196
# 1                  2                  8                     0.0       14084
# 2                  2                  8                     0.0       12427
# 3                  2                  8                     0.0       26088
# 4                  2                  8                     0.0       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# 2                  3          0   both
# 3                  4          0   both
# 4                  5          0   both

# %%
#Check the output
df_prods_cleaned.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# # MERGING THE 2 DATAFRAMES

# %%
# Dropping '_merge' column from 'orders_products_combined.pkl'
df_ords_prods_comb = df_ords_prods_comb.drop(columns = ['_merge'])

# %%
df_ords_prods_comb.shape
# Out:
# (32434489, 11)

# %%
#Merging the dataframes
df_ords_prods_merged = df_ords_prods_comb.merge(df_prods_cleaned, on ='product_id', indicator= True)

# %%
df_ords_prods_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    order_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                  2                  8                     0.0         196
# 1                  3                  7                    15.0         196
# 2                  3                 12                    21.0         196
# 3                  4                  7                    29.0         196
# 4                  4                 15                    28.0         196
#
#    add_to_cart_order  reordered  Unnamed: 0_y product_name  aisle_id  \
# 0                  1          0           195         Soda        77
# 1                  1          1           195         Soda        77
# 2                  1          1           195         Soda        77
# 3                  1          1           195         Soda        77
# 4                  1          1           195         Soda        77
#
#    department_id  prices _merge
# 0              7     9.0   both
# 1              7     9.0   both
# 2              7     9.0   both
# 3              7     9.0   both
# 4              7     9.0   both

# %%
df_ords_prods_merged['_merge'].value_counts()
# Out:
# both          32406041
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Dropping 'unnamed 0.1' and 'unnamed 0_x' columns from 'ords_prods_merged.pkl'
df_ords_prods_merged = df_ords_prods_merged.drop(columns = ['Unnamed: 0.1','Unnamed: 0_x','Unnamed: 0_y'])

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# 1         Soda        77              7     9.0   both
# 2         Soda        77              7     9.0   both
# 3         Soda        77              7     9.0   both
# 4         Soda        77              7     9.0   both

# %%
#Export to PKL
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
