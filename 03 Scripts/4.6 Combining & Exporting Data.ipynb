# %% [markdown]
# # 4.6 COMBINING & EXPORTING DATA
# ** **
#
# **SCRIPT CONTENTS:**
#
# 1. Importing Libraries & Files
# 2. Merging DataFrame
# 3. Exporting Merged DataFrame: **orders_products_merged.pkl**

# %% [markdown]
# ** **
# #### 1. IMPORTING LIBRARIES & FILES

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Document File Location
path = r'C:\Users\G\12-2022 Instacart Basket Analysis'

# %%
# Import Clean Product Dataframe
df_prodsC = pd.read_csv(os.path.join(path, '02 Data','Prepared Data','Product Data Clean.csv'), index_col = False)

# %%
# Import Merged Orders & Product file in Pickle Format
df_ords_prods_comb = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Check Merge file output
df_ords_prods_comb.head()
# Out:
#    order_id  customer_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                  2                  8
# 1   2539329            1             1                  2                  8
# 2   2539329            1             1                  2                  8
# 3   2539329            1             1                  2                  8
# 4   2539329            1             1                  2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# ...

# %% [markdown]
# **Q4) Check the shape of the imported dataframe** _(it should be the same as the one you exported—always check!)_**.**

# %%
# Verify DataFrame Dimension (shape)

df_ords_prods_comb.shape
# Out:
# (32434489, 11)

# %% [markdown]
# **OBSERVATION:** _DataFrame shape match from previous task._

# %% [markdown]
# ** **
# #### 2. MERGING DATAFRAME
#
# **Q5) Determine a suitable way to combine the orders_products_combined dataframe with your products data set.** _Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task._

# %%
# Check Clean Product File Output

df_prodsC
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
# Check Clean Product DataFrame Dimension (Shape)

df_prodsC.shape
# Out:
# (49672, 5)

# %%
# Drop column "merge" in df_ords_prods_comb & Verify Output

df_ords_prods_comb = df_ords_prods_comb.drop(columns = ['_merge'])

df_ords_prods_comb
# Out:
#           order_id  customer_id  order_number  order_day_of_week  \
# 0          2539329            1             1                  2
# 1          2539329            1             1                  2
# 2          2539329            1             1                  2
# 3          2539329            1             1                  2
# 4          2539329            1             1                  2
# ...            ...          ...           ...                ...
# 32434484   2977660       206209            13                  1
# 32434485   2977660       206209            13                  1
# 32434486   2977660       206209            13                  1
# 32434487   2977660       206209            13                  1
# 32434488   2977660       206209            13                  1
#
#           order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                         8                     NaN          True         196
# ...

# %%
# Merge df_ords_prods_comb to Clean Product DataFrame

df_ords_prods_merge = df_ords_prods_comb.merge(df_prodsC, on = 'product_id', indicator = True)

df_ords_prods_merge
# Out:
#           order_id  customer_id  order_number  order_day_of_week  \
# 0          2539329            1             1                  2
# 1          2398795            1             2                  3
# 2           473747            1             3                  3
# 3          2254736            1             4                  4
# 4           431534            1             5                  4
# ...            ...          ...           ...                ...
# 32404854   1320836       202557            17                  2
# 32404855     31526       202557            18                  5
# 32404856    758936       203436             1                  2
# 32404857   2745165       203436             2                  3
# 32404858   3093936       205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                         8                     NaN          True         196
# ...

# %% [markdown]
# **Q6. Confirm the results of the merge using the merge flag.**

# %%
df_ords_prods_merge['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# ** **
# #### 3. EXPORTING MERGED DATAFRAME

# %%
# EXPORT Merge File to Pickle Format

df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
