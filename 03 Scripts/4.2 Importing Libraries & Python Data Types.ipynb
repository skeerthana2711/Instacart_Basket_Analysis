# %% [markdown]
# # 01.Importing Libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
x=50

# %%
type(x)
# Out:
# int

# %%
print(x)
# Out:
# 50

# %%
y=100

# %%
print(y)
# Out:
# 100

# %%
z=150

# %%
print(x+50)
# Out:
# 100

# %%
print(z-x)
# Out:
# 100

# %%
a=10.26

# %%
b=3.41

# %%
print(a/b)
# Out:
# 3.0087976539589443

# %%
c=2.82

# %%
print(a/c)
# Out:
# 3.638297872340426

# %%
d='Hello,'

# %%
e='World'

# %%
print(d+e)
# Out:
# Hello,World

# %%
c='Rostock'

# %%
print(c)
# Out:
# Rostock

# %%
a='Fifa '

# %%
b='Worldcup'

# %%
print(a+b)
# Out:
# Fifa Worldcup

# %%
n= 'chololates'

# %%
n=n*100

# %%
print(n)
# Out:
# ...
